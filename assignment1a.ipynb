# %% [markdown]
# <a href="https://colab.research.google.com/github/nolanortinau/Nolan_INFO4670_Fall2026-/blob/main/assignment1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello, INFO4670!")
# Out:
# hello, INFO4670!
